# %% [markdown]
# ### Q2

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def step_func (Vec_len):
    len_ = vec_len/3
    step = np.zeros([1,len_])
    step = np.append(step,np.ones([1,len_]))
    step = np.append(step,np.zeros([1,len_]))
    print(step)
    return
def upwind(X,T,u):
    (X[1]-X[0])
    return

# %%
len_ones = 10
step = np.zeros([1,len_ones*3])
step = np.append(step,np.ones([1,len_ones]))
step = np.append(step,np.zeros([1,len_ones*3]))
plt.plot(step); plt.show()
