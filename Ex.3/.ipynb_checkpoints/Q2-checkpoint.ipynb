# %% [markdown]
# ### Q2

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def step_func (Vec_len):
    x = np.linspace(0, 1, Vec_len)  
    y = np.abs(np.where(np.sign(np.cos(2 * np.pi / 1 * x)) > 0, 1, 0)-1) # fliiping sides
    return y

def goust_func(a):
    a[0] = a[-1]; # a_0 = a_N-1
    a = np.append(a,a[1]) # a_N = a_1
    a = np.append(a[-3],a) # a_-1 = a_N-2
    return a
    
def upwind_t(a,C):
    a = goust_func(a)
    ai = a[1:]; aii = a[0:-1]
    return ai - C*(ai-aii)


def upwind_x(a,dx):
    a_ = a[1:]
    a_[0] = a_[-1]
    return a_

def eps_func(a_end,a0,N):
    dx = 1/N
    return dx * sum((a_end-a0)**2)

def upwind_advection(C=0.5, N=64, u=1,plot_init=True,plot_mid=True,plot_end=True):
    dx = 1/N; T = 1/u; dt = C/u * dx
    step = []
    step.append(step_func(N))
    t_vec = np.linspace(0,T,round(1/dt)+1)
    x_vec = np.linspace(0,1,N)
    for tt in range(len(t_vec)):
        
        step_t = upwind_t(step[-1],C)
        step_tx = upwind_x(step_t,dx)
        step.append(step_tx)
        
        if tt%50 == 0 and plot_mid == True:   
            plt.plot(x_vec,step[-1]); plt. title (f't/T = %{t_vec[tt]/T*100:.2f}'); plt.show() 
    if plot_end == True:
        if plot_init == True:
            plt.plot(x_vec,step[0]); plt. title (f'N = {N} t/T = %{t_vec[tt]/T*100:.2f}')
        
        plt.plot(x_vec,step[-1]); plt. title (f'N = {N} t/T = %{t_vec[tt]/T*100:.2f}'); plt.show() 
        plt.show()

    return step


    print("The time stpes dt the sysem is for CLF is between 0 to 1, so the maximal dt is then dx/u where dx=1/N is the grid step")
if upwind_advection:
    upwind_advection()

# %%
power_vec = np.arange(6,15,1);
N_vec = 2**power_vec
eps = []
for N in N_vec:
    a = upwind_advection(C=0.5 ,N=N , u=1, plot_init=True, plot_mid=False, plot_end=True)
    eps.append(eps_func(a[-1],a[0],N))
    print(f'eps = {eps[-1]:.5e}')
# Out:
# eps = 4.62155e-02
# eps = 3.09513e-02
# eps = 2.12723e-02
# eps = 1.48241e-02
# eps = 1.04051e-02
# eps = 7.33026e-03
# eps = 5.17363e-03
# eps = 3.65490e-03
# eps = 2.58320e-03

# %%
for n in range(len(N_vec)):
    N = N_vec[n]
    e = eps[n]
    print (f"The error for N = {N} is eps={e:.2e}")
# Out:
# The error for N = 64 is eps=4.62e-02
# The error for N = 128 is eps=3.10e-02
# The error for N = 256 is eps=2.13e-02
# The error for N = 512 is eps=1.48e-02
# The error for N = 1024 is eps=1.04e-02
# The error for N = 2048 is eps=7.33e-03
# The error for N = 4096 is eps=5.17e-03
# The error for N = 8192 is eps=3.65e-03
# The error for N = 16384 is eps=2.58e-03

# %% [markdown]
# ##### b

# %%
def step_func (Vec_len):
    x = np.linspace(0, 1, Vec_len)  
    y = np.abs(np.where(np.sign(np.cos(2 * np.pi / 1 * x)) > 0, 1, 0)-1) # fliiping sides
    return y

def goust_func(a):
    # print(a)
    a[0] = a[-1]; # a_0 = a_N-1
    a = np.append(a,a[1]) # a_N = a_1
    a = np.append(a,a[2])
    a = np.append(a[-4],a) # a_-1 = a_N-2
    a = np.append(a[-5],a) # a_-2 = a_N-3
    return a
    
def upwind_t(a,a_prev_n,C):
    a = goust_func(a)
    a_prev_n =  goust_func(a_prev_n)
    
    aip1 = a[2:]; aim1 = a[0:-2]
    # print(len(a_prev_n))
    return a_prev_n[1:-1] - C*(aip1-aim1)


def upwind_x(a,dx):
    a_ip1 = a[2:]
    a_im1 = a[:-2]
    a_ = a[1:-1]
    # print(len(a_))
    # a_ = (a_ip1 - a_im1)
    a_[0] = a_[-1]
    # print(len(a_))
    return a_

def eps_func(a_end,a0,N):
    dx = 1/N
    return dx * sum((a_end-a0)**2)




def leapfrog_func(C=0.1, N=2**6, u=1,plot_init=True,plot_mid=False,plot_end=True):
    dx = 1/N; T = 1/u; dt = C/u * dx
    step = []
    stepm2 = np.zeros(N)
    # print(stepm2[0])
    # step.append(stepm2)
    step.append(step_func(N))
    step.append(step_func(N))
    # print(step[-1])
    t_vec = np.linspace(0,T,round(1/dt)+1)
    x_vec = np.linspace(0,1,N)
    
    for tt in range(len(t_vec)):
        
        step_t = upwind_t(step[-1],step[-2],C)
        step_tx = upwind_x(step_t,dx)
        # print(len(step_tx))
        step.append(step_tx)
        if tt%50 == 0 and plot_mid == True:   
            plt.plot(x_vec,step[-1]); plt. title (f't/T = %{t_vec[tt]/T*100:.2f}'); plt.show() 
    if plot_end == True:
        if plot_init == True:
            plt.plot(x_vec,step[1]); plt. title (f'N = {N} t/T = %{t_vec[tt]/T*100:.2f}')
        
        plt.plot(x_vec,step[-1]); plt. title (f'N = {N} t/T = %{t_vec[tt]/T*100:.2f}'); plt.show() 
        plt.show()

    return step
        
if leapfrog_func:
    leapfrog_func()

# %%
power_vec = np.arange(6,15,1);
N_vec = 2**power_vec
eps = []
for N in N_vec:
    a = upwind_advection(C=0.5 ,N=N , u=1, plot_init=True, plot_mid=False, plot_end=True)
    eps.append(eps_func(a[-1],a[0],N))
    print(f'eps = {eps[-1]:.5e}')
# Out:
# eps = 5.42275e-02
# eps = 2.86319e-02
# eps = 1.79464e-02
# eps = 1.06991e-02
# eps = 7.01976e-03
# eps = 4.36255e-03
# eps = 2.76012e-03
# eps = 1.75364e-03
# eps = 1.11276e-03

# %%
for n in range(len(N_vec)):
    N = N_vec[n]
    e = eps[n]
    print (f"The error of leapfrog for N = {N} is eps={e:.2e}")
# Out:
# The error of leapfrog for N = 64 is eps=5.42e-02
# The error of leapfrog for N = 128 is eps=2.86e-02
# The error of leapfrog for N = 256 is eps=1.79e-02
# The error of leapfrog for N = 512 is eps=1.07e-02
# The error of leapfrog for N = 1024 is eps=7.02e-03
# The error of leapfrog for N = 2048 is eps=4.36e-03
# The error of leapfrog for N = 4096 is eps=2.76e-03
# The error of leapfrog for N = 8192 is eps=1.75e-03
# The error of leapfrog for N = 16384 is eps=1.11e-03
