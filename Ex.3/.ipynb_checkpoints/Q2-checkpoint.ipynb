# %% [markdown]
# ### Q2

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def step_func (Vec_len):
    x = np.linspace(0, 1, Vec_len)  
    y = np.abs(np.where(np.sign(np.cos(2 * np.pi / 1 * x)) > 0, 1, 0)-1) # fliiping sides
    return y

def goust_func(a):
    a[0] = a[-1]; # a_0 = a_N-1
    a = np.append(a,a[1]) # a_N = a_1
    a = np.append(a[-3],a) # a_-1 = a_N-2
    return a
    
def upwind_t(a,C):
    # print (a)
    a = goust_func(a)
    # print(a)
    ai = a[1:]; aii = a[0:-1]
    ai_p1 = ai - C*(ai-aii)
    return ai - C*(ai-aii)
    # return ai_p1[1:-1]

def upwind_x(a,dx):
    a_ = a[1:]
    a_[0] = a_[-1]
    # a_temp = a
    # a[1:-2] = a[1:]
    # a = a+dx
    # a[0] = a[-1]
    return a_

def main():
    C = 0.5
    N = 64; dx = 1/N
    u = 1 ; T = 1/u
    dt = C/u * dx
    step = []
    step.append(step_func(N))
    print(len(step[-1]))
    # print(step_func(N))
    # print(step[0])
    # step_0 = 0
    t_vec = np.linspace(0,T,round(1/dt)+1)
    x_vec = np.linspace(0,1,N)
    # print(t_vec)
    # print(goust_func(step[-1]))
    
    for tt in range(len(t_vec)):
        
        step_t = upwind_t(step[-1],C)
        # print(len(step_t))
        step_tx = upwind_x(step_t,dx)
        # print(len(step_tx))
        step.append(step_tx)
         
        
        # print(i)
        # if tt==0:
            # step.append(upwind(step[-1],step_0,C))
        # else:
            # print(step)
            # step.append(upwind(step[-1],step[-2],C))
        if tt%50 == 0:   
            # plt.title (f'RK dt = {dt:.1e}' )
            plt.plot(x_vec,step[-1]); plt. title (f't/T = %{t_vec[tt]/T*100:.2f}'); plt.show() 
    plt.plot(x_vec,step[-1]); plt. title (f't/T = %{t_vec[tt]/T*100:.2f}'); plt.show() 
    print(t_vec[-1])
    plt.show()


    print("The time stpes dt the sysem is for CLF is between 0 to 1, so the maximal dt is then dx/u where dx=1/N is the grid step")
if main:
    main()
# Out:
# 64
# 1.0
# The time stpes dt the sysem is for CLF is between 0 to 1, so the maximal dt is then dx/u where dx=1/N is the grid step
